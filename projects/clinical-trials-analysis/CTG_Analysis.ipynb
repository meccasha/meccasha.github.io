# %%
import pandas as pd
import sqlite3
import plotly.express as px
from plotly.subplots import make_subplots

date_parser = {
    "StudyStartDate": {
        "format": r"%y/%m/%d"
    },
    "StudyCompletionDate": {
        "format": r"%y/%m/%d"
    },
    "LastUpdatePostDate": {
        "format": r"%y/%m/%d"
    }
}

# %%
conn = sqlite3.connect(r'C:\Users\meccas\Databases\CTG_Prostate.db')

query = """
SELECT 
    COUNT(i.Intervention) as InterventionCount, m.nctID, i.Intervention, i.InterventionType
FROM 
    CTGMain as m 
LEFT JOIN 
    CTGInterventions as i 
    ON m.nctID=i.nctID 
WHERE 
    StudyType='interventional'
AND 
    PrimaryPurpose='treatment'
AND
    InterventionType='drug'
GROUP BY 
    i.Intervention 
ORDER BY 
    InterventionCount desc;"""

meshquery = """
SELECT 
    COUNT(mi.MeshIntervention) as MeshInterventionCount, m.nctID, mi.MeshIntervention, i.InterventionType
FROM 
    CTGMain as m 
LEFT JOIN 
    CTGMeshInterventions as mi 
    ON m.nctID=mi.nctID
LEFT JOIN
    CTGInterventions as i
    ON m.nctID=i.nctID
WHERE 
    StudyType='interventional'
AND
    PrimaryPurpose='treatment'
AND
    i.InterventionType='drug'
GROUP BY 
    mi.MeshIntervention 
ORDER BY 
    MeshInterventionCount desc;"""

interventional_df = pd.read_sql_query(query, conn, parse_dates=date_parser)
mesh_interventional_df = pd.read_sql_query(meshquery, conn, parse_dates=date_parser)
conn.close()

print(interventional_df[-10:-1])
print(mesh_interventional_df)
# Out:
#       InterventionCount        nctID  \
# 1715                  1  nct01513733
# 1716                  1  nct06849544
# 1717                  1  nct06849544
# 1718                  1  nct07024030
# 1719                  1  nct06849544
# 1720                  1  nct06849544
# 1721                  1  nct07024030
# 1722                  1  nct03796195
# 1723                  1  nct06705686
#
#                                            Intervention InterventionType
# 1715                                             0.5 mg             drug
# 1716  0.06mg/kg zopocianine given days prior to surgery             drug
# 1717         0.06mg/kg zopocianine given day of surgery             drug
# 1718                                          0.04mg/kg             drug
# 1719   0.03mg/kg zopocianine given day prior to surgery             drug
# 1720         0.03mg/kg zopocianine given day of surgery             drug
# 1721                                          0.02mg/kg             drug
# 1722                                    .5% bupivacaine             drug
# 1723                                           (r)-9bms             drug
#      MeshInterventionCount        nctID  \
# 0                      920  nct06568094
# 1                      810  nct00193271
# 2                      637  nct02034552
# 3                      609  nct02034552
# 4                      537  nct01076335
# ..                     ...          ...
# 730                      1  nct03403595
# 731                      1  nct00716794
# 732                      1  nct04159896
# 733                      1  nct01352208
# 734                      1  nct00036075
#
#                                       MeshIntervention InterventionType
# 0                                           prednisone             drug
# 1                                            docetaxel             drug
# 2                                         enzalutamide             drug
# 3                                  abiraterone acetate             drug
# 4                                           leuprolide             drug
# ..                                                 ...              ...
# 730                                  177lu-eb-psma-617             drug
# 731                     17-ethynylandrostane-3,17-diol             drug
# 732  11-(2-methylpropyl)-12,13-dihydro-2-methyl-8-(...             drug
# 733  1-(1-((5-methoxy-1h-indol-2-yl)carbonyl)piperi...             drug
# 734  (5-fluoro-2-methyl-1-(4-pyridyl)methylene-3-(n...             drug
#
# [735 rows x 4 columns]

# %%
fig = px.bar(interventional_df[:10], x='Intervention', y='InterventionCount', 
             hover_data='InterventionCount', color='Intervention', 
             title='Ten Most Prevalent Prostate Cancer Interventions')
fig.update_layout(showlegend=False)
fig.show()

# %%
mesh_interventional_df = mesh_interventional_df[mesh_interventional_df['MeshIntervention'] != 'null']
fig = px.bar(mesh_interventional_df[:10], x='MeshIntervention', y='MeshInterventionCount', 
             hover_data='MeshInterventionCount', color='MeshIntervention', 
             title='Ten Most Prevalent Prostate Cancer MeSH Interventions')
fig.update_layout(showlegend=False)
fig.show()

# %% [markdown]
# Now we look at top MeSH interventions in last 5 years

# %%
date_parser = {
    "StudyStartDate": {
        "format": r"%y/%m/%d"
    },
    "StudyCompletionDate": {
        "format": r"%y/%m/%d"
    },
    "LastUpdatePostDate": {
        "format": r"%y/%m/%d"
    }
}

conn = sqlite3.connect(r'C:\Users\meccas\Databases\CTG_Prostate.db')
meshquery1 = """
SELECT 
    COUNT(mi.MeshIntervention) as MeshInterventionCount, m.*, mi.MeshIntervention, i.InterventionType
FROM
    CTGMain as m
LEFT JOIN
    CTGMeshInterventions as mi
    ON m.nctID=mi.nctID
LEFT JOIN
    CTGInterventions as i
    ON m.nctID=i.nctID
WHERE
    StudyType='interventional'
AND
    PrimaryPurpose='treatment'
AND
    StudyStartDate >= '2020-01-01'
AND
    InterventionType='drug'
GROUP BY
    mi.MeshIntervention
ORDER BY
    MeshInterventionCount desc;
"""
mesh_5yr_interventional_df = pd.read_sql_query(meshquery1, conn, parse_dates=date_parser)
conn.close()

print(mesh_5yr_interventional_df)
# Out:
#      MeshInterventionCount        nctID  \
# 0                      299  nct06863272
# 1                      246  nct03649841
# 2                      242  nct06329830
# 3                      183  nct05521412
# 4                      169  nct04523207
# ..                     ...          ...
# 276                      1  nct06129851
# 277                      1  nct05011188
# 278                      1  nct05574712
# 279                      1  nct05501548
# 280                      1  nct04702737
#
#                                             BriefTitle      Acronym  \
# 0    a clinical study of ifinatamab deruxtecan base...         null
# 1    antiandrogen therapy, abiraterone acetate, and...         null
# 2    177lu-psma, niraparib/aa plus prednisone for p...       lunaar
# 3    evaluation of radioligand treatment in men wit...       violet
# 4    a study of apalutamide (adjuvant treatment) an...         null
# ..                                                 ...          ...
# 276  relugolix in combination with radiation therap...         null
# 277  for46 in combination with enzalutamide in pati...         null
# 278  a neoadjuvant study of abiraterone acetate, le...         null
# 279  phase ii study of parp inhibitor olaparib and ...         null
# 280  a study of amg 757 in participants with neuroe...  dellpro-300
#
#                                                OrgName    Investigator  \
# 0                              merck sharp & dohme llc            null
# 1                             university of washington       jing zeng
# 2                         baptist health south florida            null
# 3             peter maccallum cancer centre, australia            null
# 4                  janssen research & development, llc            null
# ..                                                 ...             ...
# 276                university of kansas medical center    xinglei shen
# 277            university of california, san francisco  rahul aggarwal
# 278  sidney kimmel comprehensive cancer center at j...            null
# 279  sidney kimmel comprehensive cancer center at j...            null
# 280                                              amgen            null
#
#                                                Sponsor          OverallStatus  \
# 0                              merck sharp & dohme llc             recruiting
# 1                             university of washington             terminated
# 2                         baptist health south florida              withdrawn
# 3             peter maccallum cancer centre, australia             recruiting
# 4                  janssen research & development, llc              completed
# ..                                                 ...                    ...
# 276                university of kansas medical center     not_yet_recruiting
# 277                                     rahul aggarwal  active_not_recruiting
# 278  sidney kimmel comprehensive cancer center at j...              withdrawn
# 279  sidney kimmel comprehensive cancer center at j...             terminated
# 280                                              amgen              completed
#
#     Interventional Model FDARegulated  ... NumDeaths NumAffectedSeriousEvent  \
# 0               parallel         true  ...      null                    null
# 1               parallel         true  ...         0                       0
# 2           single_group         true  ...      null                    null
# 3           single_group        false  ...      null                    null
# 4           single_group         true  ...         0                      16
# ..                   ...          ...  ...       ...                     ...
# 276             parallel         true  ...      null                    null
# 277           sequential         true  ...      null                    null
# 278         single_group        false  ...      null                    null
# 279         single_group         true  ...         0                       0
# 280           sequential         true  ...        35                      27
#
#     NumAffectedOtherEvent HasResults StudyStartDate StudyCompletionDate  \
# 0                    null      false     2025-07-03          2030-02-24
# 1                       2       true     2020-06-29          2023-02-01
# 2                    null      false     2024-10-01          2028-10-01
# 3                    null      false     2022-09-29          2026-12-01
# 4                     115       true     2020-08-19          2023-10-25
# ..                    ...        ...            ...                 ...
# 276                  null      false     2023-11-20          2026-10-23
# 277                  null      false     2022-01-19          2027-07-31
# 278                  null      false     2024-01-01          2026-07-01
# 279                     4       true     2023-06-30          2024-10-14
# 280                    40       true     2021-06-10          2024-07-22
#
#      LastUpdatePostDate       StudyType           MeshIntervention  \
# 0            2025-11-12  interventional               enzalutamide
# 1            2023-10-26  interventional        abiraterone acetate
# 2            2024-09-19  interventional                 prednisone
# 3            2025-04-06  interventional                       null
# 4            2025-04-25  interventional                apalutamide
# ..                  ...             ...                        ...
# 276          2023-11-13  interventional               bone density
# 277          2025-08-27  interventional  blood specimen collection
# 278          2024-03-18  interventional                 belzutifan
# 279          2025-01-29  interventional              ascorbic acid
# 280          2025-09-12  interventional                    amg 757
#
#     InterventionType
# 0               drug
# 1               drug
# 2               drug
# 3               drug
# 4               drug
# ..               ...
# 276             drug
# 277             drug
# 278             drug
# 279             drug
# 280             drug
#
# [281 rows x 29 columns]

# %%
mesh_5yr_interventional_df = mesh_5yr_interventional_df[mesh_5yr_interventional_df['MeshIntervention'] != 'null']
fig = px.bar(mesh_5yr_interventional_df[:10], x='MeshIntervention', y='MeshInterventionCount', 
             hover_data='MeshInterventionCount', color='MeshIntervention', 
             title='Ten Most Prevalent Prostate Cancer Drug MeSH Interventions Since 2020')
fig.update_layout(showlegend=False)
fig.update_xaxes(automargin=True)
fig.show()

# %% [markdown]
# What about clinical trials that are

# %%
date_parser = {
    "StudyStartDate": {
        "format": r"%y/%m/%d"
    },
    "StudyCompletionDate": {
        "format": r"%y/%m/%d"
    },
    "LastUpdatePostDate": {
        "format": r"%y/%m/%d"
    }
}

conn = sqlite3.connect(r'C:\Users\meccas\Databases\CTG_Prostate.db')
meshquery1 = """
SELECT 
    m.*, mi.MeshIntervention, i.InterventionType, 
    COUNT(case p.Phase when 'early_phase1' then 1 else null end) as EPhase1Count,
    COUNT(case p.Phase when 'phase1' then 1 else null end) as Phase1Count,
    COUNT(case p.Phase when 'phase2' then 1 else null end) as Phase2Count,
    COUNT(case p.Phase when 'phase3' then 1 else null end) as Phase3Count,
    COUNT(case p.Phase when 'phase4' then 1 else null end) as Phase4Count,
    COUNT(mi.MeshIntervention) as MeshInterventionCount
FROM
    CTGMain as m
LEFT JOIN
    CTGMeshInterventions as mi
    ON m.nctID=mi.nctID
LEFT JOIN
    CTGInterventions as i
    ON m.nctID=i.nctID
LEFT JOIN
    CTGPhases as p
    ON m.nctID=p.nctID
WHERE
    StudyType='interventional'
AND
    PrimaryPurpose='treatment'
AND
    StudyStartDate >= '2020-01-01'
AND
    InterventionType='drug'
GROUP BY
    mi.MeshIntervention
ORDER BY
    MeshInterventionCount desc;
"""
mesh_5yr_interventional_df = pd.read_sql_query(meshquery1, conn, parse_dates=date_parser)
conn.close()

print(mesh_5yr_interventional_df)
# Out:
#            nctID                                         BriefTitle  \
# 0    nct06863272  a clinical study of ifinatamab deruxtecan base...
# 1    nct06329830  177lu-psma, niraparib/aa plus prednisone for p...
# 2    nct03649841  antiandrogen therapy, abiraterone acetate, and...
# 3    nct05521412  evaluation of radioligand treatment in men wit...
# 4    nct04126070  nivolumab + docetaxel + adt in mhspc patients ...
# ..           ...                                                ...
# 276  nct06029998  bortezomib in patients with metastatic castrat...
# 277  nct06129851  relugolix in combination with radiation therap...
# 278  nct05574712  a neoadjuvant study of abiraterone acetate, le...
# 279  nct05501548  phase ii study of parp inhibitor olaparib and ...
# 280  nct04702737  a study of amg 757 in participants with neuroe...
#
#          Acronym                                            OrgName  \
# 0           null                            merck sharp & dohme llc
# 1         lunaar                       baptist health south florida
# 2           null                           university of washington
# 3         violet           peter maccallum cancer centre, australia
# 4           null                       dana-farber cancer institute
# ..           ...                                                ...
# 276     borxpten                                 university of utah
# 277         null                university of kansas medical center
# 278         null  sidney kimmel comprehensive cancer center at j...
# 279         null  sidney kimmel comprehensive cancer center at j...
# 280  dellpro-300                                              amgen
#
#         Investigator                                            Sponsor  \
# 0               null                            merck sharp & dohme llc
# 1               null                       baptist health south florida
# 2          jing zeng                           university of washington
# 3               null           peter maccallum cancer centre, australia
# 4    xiao x. wei, md                                    xiao x. wei, md
# ..               ...                                                ...
# 276             null                                 university of utah
# 277     xinglei shen                university of kansas medical center
# 278             null  sidney kimmel comprehensive cancer center at j...
# 279             null  sidney kimmel comprehensive cancer center at j...
# 280             null                                              amgen
#
#              OverallStatus Interventional Model FDARegulated GenderBased  ...  \
# 0               recruiting             parallel         true        null  ...
# 1                withdrawn         single_group         true        null  ...
# 2               terminated             parallel         true        true  ...
# 3               recruiting         single_group        false        true  ...
# 4    active_not_recruiting             parallel         true        null  ...
# ..                     ...                  ...          ...         ...  ...
# 276             recruiting         single_group         true        null  ...
# 277     not_yet_recruiting             parallel         true        null  ...
# 278              withdrawn         single_group        false        null  ...
# 279             terminated         single_group         true        null  ...
# 280              completed           sequential         true        true  ...
#
#     LastUpdatePostDate       StudyType     MeshIntervention InterventionType  \
# 0           2025-11-12  interventional         enzalutamide             drug
# 1           2024-09-19  interventional           prednisone             drug
# 2           2023-10-26  interventional  abiraterone acetate             drug
# 3           2025-04-06  interventional                 null             drug
# 4           2025-08-14  interventional            docetaxel             drug
# ..                 ...             ...                  ...              ...
# 276         2024-11-14  interventional           bortezomib             drug
# 277         2023-11-13  interventional         bone density             drug
# 278         2024-03-18  interventional           belzutifan             drug
# 279         2025-01-29  interventional        ascorbic acid             drug
# 280         2025-09-12  interventional              amg 757             drug
#
#     EPhase1Count  Phase1Count Phase2Count Phase3Count Phase4Count  \
# 0              0           89         183          87           4
# 1              0           83         131          68           4
# 2              0           77         144          50           4
# 3              8          117          89           9           0
# 4              0           55          94          62           0
# ..           ...          ...         ...         ...         ...
# 276            0            0           1           0           0
# 277            0            0           1           0           0
# 278            0            0           1           0           0
# 279            0            0           1           0           0
# 280            0            1           0           0           0
#
#     MeshInterventionCount
# 0                     363
# 1                     286
# 2                     275
# 3                     232
# 4                     211
# ..                    ...
# 276                     1
# 277                     1
# 278                     1
# 279                     1
# 280                     1
#
# [281 rows x 34 columns]

# %%
mesh_5yr_interventional_df = mesh_5yr_interventional_df[mesh_5yr_interventional_df['MeshIntervention'] != 'null']
mesh_5yr_interventional_df['MeshIntervention'] = mesh_5yr_interventional_df['MeshIntervention'].astype(str).apply(lambda x: x if len(x) <= 20 else x[:20] + '...')
mesh_5yr_interventional_df.rename(columns={'EPhase1Count': 'Early Phase 1', 'Phase1Count': 'Phase 1', 'Phase2Count': 'Phase 2', 'Phase3Count': 'Phase 3', 'Phase4Count': 'Phase 4'}, inplace=True)
fig = px.bar(mesh_5yr_interventional_df[:10], x='MeshIntervention', y=['Early Phase 1', 'Phase 1', 'Phase 2', 'Phase 3', 'Phase 4'], 
             hover_data='MeshInterventionCount',
             orientation='v', width=800, height=600)
# fig.update_layout(margin=dict(l=20, r=20, t=100, b=5))
fig.show()

# %%
date_parser = {
    "StudyStartDate": {
        "format": r"%y/%m/%d"
    },
    "StudyCompletionDate": {
        "format": r"%y/%m/%d"
    },
    "LastUpdatePostDate": {
        "format": r"%y/%m/%d"
    }
}

conn = sqlite3.connect(r'C:\Users\meccas\Databases\CTG_Prostate.db')
meshquery1 = """
SELECT 
    m.*, 
    lo.State, 
    lo.Country, 
    COUNT(lo.State) as StateCount
FROM
    CTGMain as m
LEFT JOIN
    CTGMeshInterventions as mi
    ON m.nctID=mi.nctID
LEFT JOIN
    CTGInterventions as i
    ON m.nctID=i.nctID
LEFT JOIN
    CTGLocations as lo
    ON m.nctID=lo.nctID
WHERE
    StudyType='interventional'
AND
    PrimaryPurpose='treatment'
AND
    StudyStartDate >= '2020-01-01'
AND
    InterventionType='drug'
GROUP BY
    lo.State
ORDER BY
    StateCount desc;
"""
state_df = pd.read_sql_query(meshquery1, conn, parse_dates=date_parser)
conn.close()

print(state_df)
# Out:
#            nctID                                         BriefTitle  Acronym  \
# 0    nct05580107           mdpk67b in patients with prostate cancer     null
# 1    nct04381832  adenosine receptor antagonist combination ther...     null
# 2    nct05458544  [lu-177]ludotadipep in castration-resistant pr...   lucida
# 3    nct05458544  [lu-177]ludotadipep in castration-resistant pr...   lucida
# 4    nct05053152  testing the addition of the drug relugolix to ...     null
# ..           ...                                                ...      ...
# 581  nct05794906  a study to compare darolutamide given with and...  arastep
# 582  nct05973149  trial of qlh12016 in patients with metastatic ...     null
# 583  nct05939414  an open-label study comparing lutetium (177lu)...  psma-dc
# 584  nct05794906  a study to compare darolutamide given with and...  arastep
# 585  nct06827080  study on the safety, tolerability, and prelimi...     null
#
#                            OrgName   Investigator  \
# 0                 med discovery sa           null
# 1          arcus biosciences, inc.           null
# 2                       futurechem           null
# 3                       futurechem           null
# 4                     nrg oncology           null
# ..                             ...            ...
# 581                          bayer           null
# 582  qilu pharmaceutical co., ltd.           null
# 583                       novartis           null
# 584                          bayer           null
# 585      mianyang central hospital  zhengguo chen
#
#                            Sponsor          OverallStatus  \
# 0                 med discovery sa             recruiting
# 1          arcus biosciences, inc.              completed
# 2                       futurechem             recruiting
# 3                       futurechem             recruiting
# 4                     nrg oncology             recruiting
# ..                             ...                    ...
# 581                          bayer  active_not_recruiting
# 582  qilu pharmaceutical co., ltd.     not_yet_recruiting
# 583       novartis pharmaceuticals             recruiting
# 584                          bayer  active_not_recruiting
# 585                  zhengguo chen     not_yet_recruiting
#
#     Interventional Model FDARegulated GenderBased  ...  \
# 0             sequential        false        null  ...
# 1               parallel         true        null  ...
# 2           single_group         true        true  ...
# 3           single_group         true        true  ...
# 4               parallel         true        null  ...
# ..                   ...          ...         ...  ...
# 581             parallel         true        null  ...
# 582           sequential        false        null  ...
# 583             parallel         true        null  ...
# 584             parallel         true        null  ...
# 585         single_group         true        null  ...
#
#     NumAffectedSeriousEvent NumAffectedOtherEvent HasResults StudyStartDate  \
# 0                      null                  null      false     2021-08-09
# 1                      null                  null      false     2020-07-07
# 2                      null                  null      false     2022-09-01
# 3                      null                  null      false     2022-09-01
# 4                      null                  null      false     2022-04-20
# ..                      ...                   ...        ...            ...
# 581                    null                  null      false     2023-04-03
# 582                    null                  null      false     2023-08-31
# 583                    null                  null      false     2024-03-12
# 584                    null                  null      false     2023-04-03
# 585                    null                  null      false     2025-02-11
#
#     StudyCompletionDate  LastUpdatePostDate       StudyType       State  \
# 0            2024-06-30          2023-11-07  interventional  null state
# 1            2024-08-30          2025-07-22  interventional          IL
# 2            2025-06-01          2024-04-29  interventional          CA
# 3            2025-06-01          2024-04-29  interventional          PA
# 4            2029-02-01          2025-11-10  interventional          WI
# ..                  ...                 ...             ...         ...
# 581          2030-03-29          2025-11-19  interventional    campania
# 582          2026-01-01          2023-08-02  interventional     beijign
# 583          2031-10-03          2025-11-12  interventional        avon
# 584          2030-03-29          2025-11-19  interventional      apulia
# 585          2026-12-01          2025-02-14  interventional        None
#
#             Country StateCount
# 0       switzerland      41197
# 1     united states      24805
# 2     united states      23931
# 3     united states      21692
# 4     united states      18923
# ..              ...        ...
# 581           italy          1
# 582           china          1
# 583  united kingdom          1
# 584           italy          1
# 585            None          0
#
# [586 rows x 29 columns]

# %%
fig = px.scatter_geo(state_df, locations='State', locationmode='USA-states', color='StateCount', size='StateCount', scope='usa', width=1600, height=800)
fig.show()

# %%
conn = sqlite3.connect(r'C:\Users\meccas\Databases\CTG_Prostate.db')
meshquery1 = """
SELECT 
    mi.MeshIntervention, 
    SUM(m.EnrollmentCount) as EnrollmentTotal, 
    COUNT(mi.MeshIntervention) as MeshInterventionCount, 
    SUM(m.NumDeaths) as TotalDeaths, 
    ROUND(SUM(CASE WHEN m.NumDeaths)/SUM(m.EnrollmentCount)*100, 2) as PercentEnrollmentDeaths,
    ROUND(SUM(m.NumAffectedSeriousEvent)/SUM(m.EnrollmentCount)*100, 2) as PercentEnrollmentSeriousEvents,
    ROUND(SUM(m.NumAffectedOtherEvent)/SUM(m.EnrollmentCount)*100, 2) as PercentEnrollmentOtherEvents
FROM
    CTGMain as m
LEFT JOIN
    CTGMeshInterventions as mi
    ON m.nctID=mi.nctID
LEFT JOIN
    CTGInterventions as i
    ON m.nctID=i.nctID
LEFT JOIN
    CTGLocations as lo
    ON m.nctID=lo.nctID
WHERE
    StudyType='interventional'
AND
    PrimaryPurpose='treatment'
AND
    StudyStartDate >= '2020-01-01'
AND
    InterventionType='drug'
AND
    EnrollmentType='actual'
GROUP BY
    mi.MeshIntervention
ORDER BY
    MeshInterventionCount desc;
"""
outcomes_df = pd.read_sql_query(meshquery1, conn, parse_dates=date_parser)
conn.close()

print(outcomes_df)
# Out:
#                                       MeshIntervention  EnrollmentTotal  \
# 0                                           leuprolide         16826546
# 1                                            goserelin         16741143
# 2    acetyl-2-naphthylalanyl-3-chlorophenylalanyl-1...         16724809
# 3                                          apalutamide         16863890
# 4                                  triptorelin pamoate         16601466
# ..                                                 ...              ...
# 137                          blood specimen collection               44
# 138                                         belzutifan                0
# 139                                  68ga-dkfz-psma-11              163
# 140  2-(3-(1-carboxy-5-((6-fluoropyridine-3-carbony...                0
# 141  11-(2-pyrrolidin-1-ylethoxy)-14,19-dioxa-5,7,2...                6
#
#      MeshInterventionCount  TotalDeaths  PercentEnrollmentDeaths  \
# 0                     9341          8.0                      0.0
# 1                     9108          0.0                      0.0
# 2                     8522          0.0                      0.0
# 3                     6748          1.0                      0.0
# 4                     6676        156.0                      0.0
# ..                     ...          ...                      ...
# 137                      1          0.0                      0.0
# 138                      1          0.0                      NaN
# 139                      1          0.0                      0.0
# 140                      1          0.0                      NaN
# 141                      1          0.0                      0.0
#
#      PercentEnrollmentSeriousEvents  PercentEnrollmentOtherEvents
# 0                              0.00                          0.00
# 1                              0.00                          0.00
# 2                              0.00                          0.00
# 3                              0.01                          0.07
# 4                              0.01                          0.03
# ..                              ...                           ...
# 137                            0.00                          0.00
# 138                             NaN                           NaN
# 139                            0.00                          0.00
# 140                             NaN                           NaN
# 141                            0.00                        100.00
#
# [142 rows x 7 columns]

# %%
outcomes_df['MeshIntervention'] = outcomes_df['MeshIntervention'].astype(str).apply(lambda x: x if len(x) <= 20 else x[:20] + '...')
fig = px.bar(outcomes_df[:10], x='MeshIntervention', y='EnrollmentTotal', 
             hover_data=['EnrollmentTotal'],
             orientation='v', width=800, height=600)

fig.show()

# %%
fig = px.bar(outcomes_df[:10], x='MeshIntervention', y=['PercentEnrollmentDeaths', 'PercentEnrollmentSeriousEvents', 'PercentEnrollmentOtherEvents'],
             hover_data=['MeshInterventionCount', 'EnrollmentTotal', 'TotalDeaths'], orientation='v', width=1200, height=600, barmode='group')
fig.show()

# %%
date_parser = {
    "StudyStartDate": {
        "format": r"%y/%m/%d"
    },
    "StudyCompletionDate": {
        "format": r"%y/%m/%d"
    },
    "LastUpdatePostDate": {
        "format": r"%y/%m/%d"
    }
}

conn = sqlite3.connect(r'C:\Users\meccas\Databases\CTG_Prostate.db')
meshquery2 = """
SELECT
    *
FROM
    CTGMain as m
LEFT JOIN
    CTGMeshInterventions as mi
    ON m.nctID=mi.nctID
LEFT JOIN
    CTGInterventions as i
    ON m.nctID=i.nctID
LEFT JOIN
    CTGLocations as lo
    ON m.nctID=lo.nctID
WHERE
    StudyType='interventional'
AND
    PrimaryPurpose='treatment'
AND
    StudyStartDate >= '2020-01-01'
AND
    InterventionType='drug'
AND
    EnrollmentType='actual'
GROUP BY
    m.nctID
ORDER BY
    m.EnrollmentCount desc;
"""
outcomes_heatmap_df = pd.read_sql_query(meshquery2, conn, parse_dates=date_parser)
conn.close()

print(outcomes_heatmap_df)

    # mi.MeshIntervention, 
    # SUM(m.EnrollmentCount) as EnrollmentTotal, 
    # COUNT(mi.MeshIntervention) as MeshInterventionCount, 
    # SUM(m.NumDeaths) as TotalDeaths, 
    # ROUND(SUM(m.NumDeaths)/SUM(m.EnrollmentCount)*100, 2) as PercentEnrollmentDeaths,
    # ROUND(SUM(m.NumAffectedSeriousEvent)/SUM(m.EnrollmentCount)*100, 2) as PercentEnrollmentSeriousEvents,
    # ROUND(SUM(m.NumAffectedOtherEvent)/SUM(m.EnrollmentCount)*100, 2) as PercentEnrollmentOtherEvents
# Out:
#            nctID                                         BriefTitle  \
# 0    nct04513717  two studies for patients with high risk prosta...
# 1    nct04191096  efficacy and safety of pembrolizumab (mk-3475)...
# 2    nct04720157  an international prospective open-label, rando...
# 3    nct04136353  darolutamide augments standard therapy for loc...
# 4    nct05348577  study of capivasertib + docetaxel vs placebo +...
# ..           ...                                                ...
# 200  nct04225299  evaluation of efficacy of tookad® (vtp) versus...
# 201  nct03709550  enzalutamide and decitabine in treating patien...
# 202  nct03488810  apalutamide with radiotherapy and androgen dep...
# 203  nct02864784  investigating the safety, tolerability and eff...
# 204  nct02811809  apalutamide plus intermittent hormone therapy ...
#
#           Acronym                                            OrgName  \
# 0            null                                       nrg oncology
# 1            null                            merck sharp & dohme llc
# 2     psmaddition                                           novartis
# 3      dasl-hicap                               university of sydney
# 4    capitello280                                        astrazeneca
# ..            ...                                                ...
# 200          null                                 steba biotech s.a.
# 201          null                      roswell park cancer institute
# 202       arn-509  european organisation for research and treatme...
# 203          null                                    amorphical ltd.
# 204          null  the university of texas health science center,...
#
#     Investigator                                            Sponsor  \
# 0           null                                       nrg oncology
# 1           null                            merck sharp & dohme llc
# 2           null                           novartis pharmaceuticals
# 3           null                               university of sydney
# 4           null                                        astrazeneca
# ..           ...                                                ...
# 200         null                                 steba biotech s.a.
# 201         null                      roswell park cancer institute
# 202         null  european organisation for research and treatme...
# 203         null                                    amorphical ltd.
# 204         null  the university of texas health science center,...
#
#              OverallStatus Interventional Model FDARegulated GenderBased  ...  \
# 0    active_not_recruiting             parallel         true        null  ...
# 1    active_not_recruiting             parallel         true        null  ...
# 2    active_not_recruiting             parallel         true        true  ...
# 3    active_not_recruiting             parallel         true        null  ...
# 4    active_not_recruiting             parallel         true        null  ...
# ..                     ...                  ...          ...         ...  ...
# 200              withdrawn             parallel         true        null  ...
# 201              withdrawn         single_group         true        null  ...
# 202              withdrawn             parallel        false        null  ...
# 203              withdrawn             parallel        false        null  ...
# 204              withdrawn            crossover         true        null  ...
#
#           StudyType        nctID  \
# 0    interventional  nct04513717
# 1    interventional  nct04191096
# 2    interventional  nct04720157
# 3    interventional  nct04136353
# 4    interventional  nct05348577
# ..              ...          ...
# 200  interventional  nct04225299
# 201  interventional  nct03709550
# 202  interventional  nct03488810
# 203  interventional  nct02864784
# 204  interventional  nct02811809
#
#                                       MeshIntervention        nctID  \
# 0    acetyl-2-naphthylalanyl-3-chlorophenylalanyl-1...  nct04513717
# 1                                 androgen antagonists  nct04191096
# 2                                   gallium 68 psma-11  nct04720157
# 3                                         darolutamide  nct04136353
# 4                                         capivasertib  nct05348577
# ..                                                 ...          ...
# 200                                       padeliporfin  nct04225299
# 201                                         decitabine  nct03709550
# 202                                        apalutamide  nct03488810
# 203                                               null  nct02864784
# 204                                        apalutamide  nct02811809
#
#                            Intervention  InterventionType        nctID  \
# 0                           apalutamide              drug  nct04513717
# 1    androgen deprivation therapy (adt)              drug  nct04191096
# 2                        177lu-psma-617              drug  nct04720157
# 3                          darolutamide              drug  nct04136353
# 4                          capivasertib              drug  nct05348577
# ..                                  ...               ...          ...
# 200                             tookad®              drug  nct04225299
# 201                          decitabine              drug  nct03709550
# 202                         apalutamide              drug         None
# 203         amorphous calcium carbonate              drug  nct02864784
# 204                         apalutamide              drug  nct02811809
#
#             City          State           Country
# 0          akron             OH     united states
# 1        aalborg  north denmark           denmark
# 2    albuquerque             NM     united states
# 3       aberdeen     null state    united kingdom
# 4          adana     null state  turkey (türkiye)
# ..           ...            ...               ...
# 200     new york             NY     united states
# 201      buffalo             NY     united states
# 202         None           None              None
# 203    beersheba     null state            israel
# 204      houston             TX     united states
#
# [205 rows x 35 columns]
